# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/FinalModule_Coursera/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# <h1 align="center"><font size="5">Classification with Python</font></h1>

# %% [markdown]
# In this notebook we try to practice all the classification algorithms that we have learned in this course.
#
# We load a dataset using Pandas library, and apply the following algorithms, and find the best one for this specific dataset by accuracy evaluation methods.
#
# Let's first load required libraries:

# %%
# !pip install pandas 
# !pip install numpy
# !pip install matplotlib
# !pip install itertools
# !pip install scikit-learn
# Out:
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.7/site-packages (1.21.6)
# Collecting matplotlib
#   Downloading matplotlib-3.5.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 22.5 MB/s
# Requirement already satisfied: numpy>=1.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (1.21.6)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 45.9 MB/s
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (3.0.7)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.33.3-py3-none-any.whl (930 kB)
#      |████████████████████████████████| 930 kB 61.5 MB/s
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 56.7 MB/s
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: typing-extensions in /srv/conda/envs/notebook/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (4.0.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.33.3 kiwisolver-1.4.2 matplotlib-3.5.1 pillow-9.1.0
# ERROR: Could not find a version that satisfies the requirement itertools (from versions: none)
# ERROR: No matching distribution found for itertools
# Collecting scikit-learn
#   Downloading scikit_learn-1.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.8 MB)
#      |████████████████████████████████| 24.8 MB 21.9 MB/s            ��██████████████▋  | 23.0 MB 21.9 MB/s eta 0:00:01
# Collecting joblib>=0.11
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      |████████████████████████████████| 306 kB 68.4 MB/s
# Requirement already satisfied: numpy>=1.14.6 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scikit-learn) (1.21.6)
# Collecting scipy>=1.1.0
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 26 kB/s              MB 44.7 MB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.1.0 scikit-learn-1.0.2 scipy-1.7.3 threadpoolctl-3.1.0

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline

# %% [markdown]
# ### About dataset

# %% [markdown]
# This dataset is about past loans. The **Loan_train.csv** data set includes details of 346 customers whose loan are already paid off or defaulted. It includes following fields:
#
# | Field          | Description                                                                           |
# | -------------- | ------------------------------------------------------------------------------------- |
# | Loan_status    | Whether a loan is paid off on in collection                                           |
# | Principal      | Basic principal loan amount at the                                                    |
# | Terms          | Origination terms which can be weekly (7 days), biweekly, and monthly payoff schedule |
# | Effective_date | When the loan got originated and took effects                                         |
# | Due_date       | Since it’s one-time payoff schedule, each loan has one single due date                |
# | Age            | Age of applicant                                                                      |
# | Education      | Education of applicant                                                                |
# | Gender         | The gender of applicant                                                               |

# %% [markdown]
# Let's download the dataset

# %%
# !wget -O loan_train.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/loan_train.csv
# Out:
# --2022-04-29 14:00:45--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/loan_train.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23101 (23K) [text/csv]
# Saving to: ‘loan_train.csv’
#
# loan_train.csv      100%[===================>]  22.56K  --.-KB/s    in 0.08s
#
# 2022-04-29 14:00:46 (278 KB/s) - ‘loan_train.csv’ saved [23101/23101]

# %% [markdown]
# ### Load Data From CSV File

# %%
df = pd.read_csv('loan_train.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30       9/8/2016
# 1           2             2     PAIDOFF       1000     30       9/8/2016
# 2           3             3     PAIDOFF       1000     15       9/8/2016
# 3           4             4     PAIDOFF       1000     30       9/9/2016
# 4           6             6     PAIDOFF       1000     30       9/9/2016
#
#     due_date  age             education  Gender
# 0  10/7/2016   45  High School or Below    male
# 1  10/7/2016   33              Bechalor  female
# 2  9/22/2016   27               college    male
# 3  10/8/2016   28               college  female
# 4  10/8/2016   29               college    male

# %%
df.shape
# Out:
# (346, 10)

# %% [markdown]
# ### Convert to date time object

# %%
df['due_date'] = pd.to_datetime(df['due_date'])
df['effective_date'] = pd.to_datetime(df['effective_date'])
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender
# 0 2016-10-07   45  High School or Below    male
# 1 2016-10-07   33              Bechalor  female
# 2 2016-09-22   27               college    male
# 3 2016-10-08   28               college  female
# 4 2016-10-08   29               college    male

# %% [markdown]
# # Data visualization and pre-processing

# %% [markdown]
# Let’s see how many of each class is in our data set

# %%
df['loan_status'].value_counts()
# Out:
# PAIDOFF       260
# COLLECTION     86
# Name: loan_status, dtype: int64

# %% [markdown]
# 260 people have paid off the loan on time while 86 have gone into collection

# %% [markdown]
# Let's plot some columns to underestand data better:

# %%
# notice: installing seaborn might takes a few minutes
# !conda install -c anaconda seaborn -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/linux-64::certifi==2021.10.8=py37h89c1867_1
#   - conda-forge/linux-64::python_abi==3.7=2_cp37m
#   - conda-forge/noarch::prometheus_client==0.13.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::python==3.7.12=hb7a2778_100_cpython
#   - conda-forge/noarch::charset-normalizer==2.0.10=pyhd8ed1ab_0
#   - conda-forge/linux-64::setuptools==60.5.0=py37h89c1867_0
#   - conda-forge/linux-64::argon2-cffi-bindings==21.2.0=py37h5e8e339_1
#   - conda-forge/linux-64::importlib-metadata==4.10.1=py37h89c1867_0
#   - conda-forge/noarch::jinja2==3.0.3=pyhd8ed1ab_0
#   - conda-forge/noarch::websocket-client==1.2.3=pyhd8ed1ab_0
#   - conda-forge/linux-64::ipykernel==6.7.0=py37h6531663_0
#   - conda-forge/noarch::zipp==3.7.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::jupyterhub-base==1.4.2=py37h89c1867_0
#   - conda-forge/noarch::nest-asyncio==1.5.4=pyhd8ed1ab_0
#   - conda-forge/noarch::nbformat==5.1.3=pyhd8ed1ab_0
#   - conda-forge/linux-64::brotlipy==0.7.0=py37h5e8e339_1003
#   - conda-forge/linux-64::markupsafe==2.0.1=py37h5e8e339_1
#   - conda-forge/linux-64::pyrsistent==0.18.1=py37h5e8e339_0
#   - conda-forge/noarch::attrs==21.4.0=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyter_client==7.1.2=pyhd8ed1ab_0
#   - conda-forge/noarch::flit-core==3.6.0=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyter_server==1.13.4=pyhd8ed1ab_0
#   - conda-forge/noarch::pygments==2.11.2=pyhd8ed1ab_0
#   - conda-forge/noarch::pyopenssl==21.0.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::ruamel.yaml.clib==0.2.6=py37h5e8e339_0
#   - conda-forge/noarch::entrypoints==0.3=pyhd8ed1ab_1003
#   - conda-forge/noarch::requests==2.27.1=pyhd8ed1ab_0
#   - conda-forge/linux-64::cffi==1.15.0=py37h036bc23_0
#   - conda-forge/noarch::defusedxml==0.7.1=pyhd8ed1ab_0
#   - conda-forge/noarch::json5==0.9.5=pyh9f0ad1d_0
#   - conda-forge/noarch::argon2-cffi==21.3.0=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyter_telemetry==0.1.0=pyhd8ed1ab_1
#   - conda-forge/noarch::mako==1.1.6=pyhd8ed1ab_0
#   - conda-forge/noarch::babel==2.9.1=pyh44b312d_0
#   - conda-forge/noarch::wcwidth==0.2.5=pyh9f0ad1d_2
#   - conda-forge/noarch::pandocfilters==1.5.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::sniffio==1.2.0=py37h89c1867_2
#   - conda-forge/linux-64::psutil==5.9.0=py37h5e8e339_0
#   - conda-forge/noarch::matplotlib-inline==0.1.3=pyhd8ed1ab_0
#   - conda-forge/noarch::pyparsing==3.0.7=pyhd8ed1ab_0
#   - conda-forge/noarch::nteract_on_jupyter==2.1.3=py_0
#   - conda-forge/noarch::typing_extensions==4.0.1=pyha770c72_0
#   - conda-forge/noarch::decorator==5.1.1=pyhd8ed1ab_0
#   - conda-forge/noarch::blinker==1.4=py_1
#   - conda-forge/noarch::pip==21.3.1=pyhd8ed1ab_0
#   - conda-forge/noarch::webencodings==0.5.1=py_1
#   - conda-forge/linux-64::sqlalchemy==1.4.31=py37h5e8e339_0
#   - conda-forge/noarch::backports==1.0=py_2
#   - conda-forge/linux-64::mistune==0.8.4=py37h5e8e339_1005
#   - conda-forge/linux-64::cryptography==36.0.1=py37hf1a17b8_0
#   - conda-forge/noarch::certipy==0.1.3=py_0
#   - conda-forge/noarch::python-dateutil==2.8.2=pyhd8ed1ab_0
#   - conda-forge/linux-64::ipython==7.31.1=py37h89c1867_0
#   - conda-forge/linux-64::sqlite==3.37.0=h9cd32fc_0
#   - conda-forge/noarch::jsonschema==4.4.0=pyhd8ed1ab_0
#   - conda-forge/noarch::pyjwt==2.3.0=pyhd8ed1ab_1
#   - conda-forge/noarch::nbclassic==0.3.5=pyhd8ed1ab_0
#   - conda-forge/linux-64::jupyter_core==4.9.1=py37h89c1867_1
#   - conda-forge/noarch::jupyter-resource-usage==0.6.1=pyhd8ed1ab_0
#   - conda-forge/noarch::urllib3==1.26.8=pyhd8ed1ab_1
#   - conda-forge/linux-64::jedi==0.18.1=py37h89c1867_0
#   - conda-forge/noarch::jupyterlab==3.2.8=pyhd8ed1ab_0
#   - conda-forge/noarch::prompt-toolkit==3.0.24=pyha770c72_0
#   - conda-forge/noarch::ptyprocess==0.7.0=pyhd3deb0d_0
#   - conda-forge/noarch::jupyterlab_server==2.10.3=pyhd8ed1ab_0
#   - conda-forge/noarch::nbclient==0.5.10=pyhd8ed1ab_1
#   - conda-forge/noarch::bleach==4.1.0=pyhd8ed1ab_0
#   - conda-forge/noarch::ipython_genutils==0.2.0=py_1
#   - conda-forge/noarch::six==1.16.0=pyh6c4a22f_0
#   - conda-forge/noarch::testpath==0.5.0=pyhd8ed1ab_0
#   - conda-forge/noarch::backcall==0.2.0=pyh9f0ad1d_0
#   - conda-forge/linux-64::anyio==3.5.0=py37h89c1867_0
#   - conda-forge/noarch::pexpect==4.8.0=pyh9f0ad1d_2
#   - conda-forge/noarch::send2trash==1.8.0=pyhd8ed1ab_0
#   - conda-forge/noarch::idna==3.3=pyhd8ed1ab_0
#   - conda-forge/noarch::python-json-logger==2.0.1=pyh9f0ad1d_0
#   - conda-forge/linux-64::jupyterhub-singleuser==1.4.2=py37h89c1867_0
#   - conda-forge/noarch::jupyter-offlinenotebook==0.2.2=pyh1d7be83_0
#   - conda-forge/linux-64::tornado==6.1=py37h5e8e339_2
#   - conda-forge/noarch::packaging==21.3=pyhd8ed1ab_0
#   - conda-forge/noarch::wheel==0.37.1=pyhd8ed1ab_0
#   - conda-forge/linux-64::pyzmq==22.3.0=py37h336d617_1
#   - conda-forge/noarch::traitlets==5.1.1=pyhd8ed1ab_0
#   - conda-forge/linux-64::nbconvert==6.0.7=py37h89c1867_3
#   - conda-forge/linux-64::widgetsnbextension==3.5.2=py37h89c1867_1
#   - conda-forge/noarch::jupyterlab_widgets==1.0.2=pyhd8ed1ab_0
#   - conda-forge/noarch::backports.functools_lru_cache==1.6.4=pyhd8ed1ab_0
#   - conda-forge/noarch::pickleshare==0.7.5=py_1003
#   - conda-forge/noarch::parso==0.8.3=pyhd8ed1ab_0
#   - conda-forge/noarch::ipywidgets==7.6.5=pyhd8ed1ab_0
#   - conda-forge/noarch::pamela==1.0.0=py_0
#   - conda-forge/noarch::pycparser==2.21=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyterlab_pygments==0.1.2=pyh9f0ad1d_0
#   - conda-forge/noarch::oauthlib==3.1.1=pyhd8ed1ab_0
#   - conda-forge/noarch::importlib_resources==5.4.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::ruamel.yaml==0.17.19=py37h5e8e339_0
#   - conda-forge/linux-64::pycurl==7.44.1=py37h88a64d2_1
#   - conda-forge/noarch::pytz==2021.3=pyhd8ed1ab_0
#   - conda-forge/linux-64::terminado==0.12.1=py37h89c1867_1
#   - conda-forge/linux-64::pysocks==1.7.1=py37h89c1867_4
#   - conda-forge/noarch::alembic==1.7.5=pyhd8ed1ab_0
#   - conda-forge/noarch::async_generator==1.10=py_0
#   - conda-forge/linux-64::greenlet==1.1.2=py37hcd2ae1e_1
#   - conda-forge/noarch::notebook==6.3.0=pyha770c72_1
#   - conda-forge/linux-64::debugpy==1.5.1=py37hcd2ae1e_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB  anaconda
#     bottleneck-1.3.4           |   py37hce1f21e_0         138 KB  anaconda
#     brotli-1.0.9               |       he6710b0_2         402 KB  anaconda
#     ca-certificates-2022.3.29  |       h06a4308_1         129 KB  anaconda
#     cycler-0.11.0              |     pyhd3eb1b0_0          12 KB  anaconda
#     dbus-1.13.18               |       hb2f20db_0         586 KB  anaconda
#     expat-2.4.4                |       h295c915_0         211 KB  anaconda
#     fontconfig-2.13.1          |       h6c09931_0         299 KB  anaconda
#     fonttools-4.25.0           |     pyhd3eb1b0_0         674 KB  anaconda
#     freetype-2.11.0            |       h70c0345_0         943 KB  anaconda
#     giflib-5.2.1               |       h7b6447c_0          82 KB  anaconda
#     glib-2.56.2                |       hd408876_0         5.0 MB  anaconda
#     gst-plugins-base-1.14.0    |       hbbd80ab_1         6.3 MB  anaconda
#     gstreamer-1.14.0           |       hb453b48_1         3.8 MB  anaconda
#     icu-58.2                   |       he6710b0_3        22.7 MB  anaconda
#     intel-openmp-2021.4.0      |    h06a4308_3561         8.8 MB  anaconda
#     jpeg-9d                    |       h7f8727e_0         265 KB  anaconda
#     kiwisolver-1.3.2           |   py37h295c915_0          86 KB  anaconda
#     lcms2-2.12                 |       h3be6417_0         396 KB  anaconda
#     libgcc-7.2.0               |       h69d50b8_2         304 KB  anaconda
#     libgfortran-ng-7.5.0       |      ha8ba4b0_17          22 KB  anaconda
#     libgfortran4-7.5.0         |      ha8ba4b0_17         1.3 MB  anaconda
#     libpng-1.6.37              |       hbc83047_0         364 KB  anaconda
#     libtiff-4.2.0              |       h85742a9_0         640 KB  anaconda
#     libuuid-1.0.3              |       h7f8727e_2          18 KB  anaconda
#     libwebp-1.2.2              |       h55f646e_0          88 KB  anaconda
#     libwebp-base-1.2.2         |       h7f8727e_0         869 KB  anaconda
#     libxcb-1.14                |       h7b6447c_0         610 KB  anaconda
#     libxml2-2.9.12             |       h03d6c58_0         1.3 MB  anaconda
#     lz4-c-1.9.3                |       h295c915_1         216 KB  anaconda
#     matplotlib-3.5.1           |   py37h06a4308_1          28 KB  anaconda
#     matplotlib-base-3.5.1      |   py37ha18d171_1         7.4 MB  anaconda
#     mkl-2021.4.0               |     h06a4308_640       219.1 MB  anaconda
#     mkl-service-2.4.0          |   py37h7f8727e_0          59 KB  anaconda
#     mkl_fft-1.3.1              |   py37hd3c417c_0         190 KB  anaconda
#     mkl_random-1.2.2           |   py37h51133e4_0         332 KB  anaconda
#     munkres-1.1.4              |             py_0          13 KB  anaconda
#     nodejs-6.11.2              |       h3db8ef7_0        11.4 MB  anaconda
#     numexpr-2.8.1              |   py37h6abb31d_0         133 KB  anaconda
#     numpy-1.21.5               |   py37he7a7128_1          23 KB  anaconda
#     numpy-base-1.21.5          |   py37hf524024_1         6.0 MB  anaconda
#     openssl-1.1.1n             |       h7f8727e_0         3.8 MB  anaconda
#     pandas-1.3.4               |   py37h8c16a72_0        11.9 MB  anaconda
#     pcre-8.45                  |       h295c915_0         257 KB  anaconda
#     pillow-9.0.1               |   py37h22f2fdc_0         713 KB  anaconda
#     pyqt-5.9.2                 |   py37h22d08a2_1         5.6 MB  anaconda
#     qt-5.9.7                   |       h5867ecd_1        85.9 MB  anaconda
#     scipy-1.7.3                |   py37hc147768_0        21.2 MB  anaconda
#     seaborn-0.11.2             |     pyhd3eb1b0_0         223 KB  anaconda
#     sip-4.19.25                |   py37h2531618_0         295 KB  anaconda
#     sqlite-3.38.2              |       hc218d9a_0         1.5 MB  anaconda
#     zstd-1.4.5                 |       h9ceee32_0         716 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:       433.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               anaconda/linux-64::blas-1.0-mkl
#   bottleneck         anaconda/linux-64::bottleneck-1.3.4-py37hce1f21e_0
#   brotli             anaconda/linux-64::brotli-1.0.9-he6710b0_2
#   cycler             anaconda/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   dbus               anaconda/linux-64::dbus-1.13.18-hb2f20db_0
#   expat              anaconda/linux-64::expat-2.4.4-h295c915_0
#   fontconfig         anaconda/linux-64::fontconfig-2.13.1-h6c09931_0
#   fonttools          anaconda/noarch::fonttools-4.25.0-pyhd3eb1b0_0
#   freetype           anaconda/linux-64::freetype-2.11.0-h70c0345_0
#   giflib             anaconda/linux-64::giflib-5.2.1-h7b6447c_0
#   glib               anaconda/linux-64::glib-2.56.2-hd408876_0
#   gst-plugins-base   anaconda/linux-64::gst-plugins-base-1.14.0-hbbd80ab_1
#   gstreamer          anaconda/linux-64::gstreamer-1.14.0-hb453b48_1
#   intel-openmp       anaconda/linux-64::intel-openmp-2021.4.0-h06a4308_3561
#   jpeg               anaconda/linux-64::jpeg-9d-h7f8727e_0
#   kiwisolver         anaconda/linux-64::kiwisolver-1.3.2-py37h295c915_0
#   lcms2              anaconda/linux-64::lcms2-2.12-h3be6417_0
#   libgcc             anaconda/linux-64::libgcc-7.2.0-h69d50b8_2
#   libgfortran-ng     anaconda/linux-64::libgfortran-ng-7.5.0-ha8ba4b0_17
#   libgfortran4       anaconda/linux-64::libgfortran4-7.5.0-ha8ba4b0_17
#   libpng             anaconda/linux-64::libpng-1.6.37-hbc83047_0
#   libtiff            anaconda/linux-64::libtiff-4.2.0-h85742a9_0
#   libuuid            anaconda/linux-64::libuuid-1.0.3-h7f8727e_2
#   libwebp            anaconda/linux-64::libwebp-1.2.2-h55f646e_0
#   libwebp-base       anaconda/linux-64::libwebp-base-1.2.2-h7f8727e_0
#   libxcb             anaconda/linux-64::libxcb-1.14-h7b6447c_0
#   libxml2            anaconda/linux-64::libxml2-2.9.12-h03d6c58_0
#   lz4-c              anaconda/linux-64::lz4-c-1.9.3-h295c915_1
#   matplotlib         anaconda/linux-64::matplotlib-3.5.1-py37h06a4308_1
#   matplotlib-base    anaconda/linux-64::matplotlib-base-3.5.1-py37ha18d171_1
#   mkl                anaconda/linux-64::mkl-2021.4.0-h06a4308_640
#   mkl-service        anaconda/linux-64::mkl-service-2.4.0-py37h7f8727e_0
#   mkl_fft            anaconda/linux-64::mkl_fft-1.3.1-py37hd3c417c_0
#   mkl_random         anaconda/linux-64::mkl_random-1.2.2-py37h51133e4_0
#   munkres            anaconda/noarch::munkres-1.1.4-py_0
#   numexpr            anaconda/linux-64::numexpr-2.8.1-py37h6abb31d_0
#   numpy              anaconda/linux-64::numpy-1.21.5-py37he7a7128_1
#   numpy-base         anaconda/linux-64::numpy-base-1.21.5-py37hf524024_1
#   pandas             anaconda/linux-64::pandas-1.3.4-py37h8c16a72_0
#   pcre               anaconda/linux-64::pcre-8.45-h295c915_0
#   pillow             anaconda/linux-64::pillow-9.0.1-py37h22f2fdc_0
#   pyqt               anaconda/linux-64::pyqt-5.9.2-py37h22d08a2_1
#   qt                 anaconda/linux-64::qt-5.9.7-h5867ecd_1
#   scipy              anaconda/linux-64::scipy-1.7.3-py37hc147768_0
#   seaborn            anaconda/noarch::seaborn-0.11.2-pyhd3eb1b0_0
#   sip                anaconda/linux-64::sip-4.19.25-py37h2531618_0
#   zstd               anaconda/linux-64::zstd-1.4.5-h9ceee32_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2021.10.~ --> anaconda::ca-certificates-2022.3.29-h06a4308_1
#   openssl            conda-forge::openssl-1.1.1l-h7f98852_0 --> anaconda::openssl-1.1.1n-h7f8727e_0
#   sqlite              conda-forge::sqlite-3.37.0-h9cd32fc_0 --> anaconda::sqlite-3.38.2-hc218d9a_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   icu                      conda-forge::icu-69.1-h9c3ff4c_0 --> anaconda::icu-58.2-he6710b0_3
#   nodejs             conda-forge::nodejs-14.18.3-h8ca31f7_2 --> anaconda::nodejs-6.11.2-h3db8ef7_0
#
#
#
# Downloading and Extracting Packages
# libxcb-1.14          | 610 KB    | ##################################### | 100%
# jpeg-9d              | 265 KB    | ##################################### | 100%
# libuuid-1.0.3        | 18 KB     | ##################################### | 100%
# qt-5.9.7             | 85.9 MB   | ##################################### | 100%
# numpy-base-1.21.5    | 6.0 MB    | ##################################### | 100%
# bottleneck-1.3.4     | 138 KB    | ##################################### | 100%
# libgcc-7.2.0         | 304 KB    | ##################################### | 100%
# fonttools-4.25.0     | 674 KB    | ##################################### | 100%
# numpy-1.21.5         | 23 KB     | ##################################### | 100%
# fontconfig-2.13.1    | 299 KB    | ##################################### | 100%
# pcre-8.45            | 257 KB    | ##################################### | 100%
# glib-2.56.2          | 5.0 MB    | ##################################### | 100%
# brotli-1.0.9         | 402 KB    | ##################################### | 100%
# libgfortran4-7.5.0   | 1.3 MB    | ##################################### | 100%
# sqlite-3.38.2        | 1.5 MB    | ##################################### | 100%
# libwebp-1.2.2        | 88 KB     | ##################################### | 100%
# pillow-9.0.1         | 713 KB    | ##################################### | 100%
# pandas-1.3.4         | 11.9 MB   | ##################################### | 100%
# munkres-1.1.4        | 13 KB     | ##################################### | 100%
# mkl_fft-1.3.1        | 190 KB    | ##################################### | 100%
# lcms2-2.12           | 396 KB    | ##################################### | 100%
# mkl-2021.4.0         | 219.1 MB  | ##################################### | 100%
# expat-2.4.4          | 211 KB    | ##################################### | 100%
# gstreamer-1.14.0     | 3.8 MB    | ##################################### | 100%
# gst-plugins-base-1.1 | 6.3 MB    | ##################################### | 100%
# sip-4.19.25          | 295 KB    | ##################################### | 100%
# scipy-1.7.3          | 21.2 MB   | ##################################### | 100%
# libxml2-2.9.12       | 1.3 MB    | ##################################### | 100%
# libwebp-base-1.2.2   | 869 KB    | ##################################### | 100%
# nodejs-6.11.2        | 11.4 MB   | ##################################### | 100%
# libtiff-4.2.0        | 640 KB    | ##################################### | 100%
# lz4-c-1.9.3          | 216 KB    | ##################################### | 100%
# libpng-1.6.37        | 364 KB    | ##################################### | 100%
# seaborn-0.11.2       | 223 KB    | ##################################### | 100%
# blas-1.0             | 6 KB      | ##################################### | 100%
# zstd-1.4.5           | 716 KB    | ##################################### | 100%
# freetype-2.11.0      | 943 KB    | ##################################### | 100%
# ca-certificates-2022 | 129 KB    | ##################################### | 100%
# openssl-1.1.1n       | 3.8 MB    | ##################################### | 100%
# kiwisolver-1.3.2     | 86 KB     | ##################################### | 100%
# giflib-5.2.1         | 82 KB     | ##################################### | 100%
# cycler-0.11.0        | 12 KB     | ##################################### | 100%
# matplotlib-3.5.1     | 28 KB     | ##################################### | 100%
# icu-58.2             | 22.7 MB   | ##################################### | 100%
# dbus-1.13.18         | 586 KB    | ##################################### | 100%
# libgfortran-ng-7.5.0 | 22 KB     | ##################################### | 100%
# numexpr-2.8.1        | 133 KB    | ##################################### | 100%
# mkl-service-2.4.0    | 59 KB     | ##################################### | 100%
# matplotlib-base-3.5. | 7.4 MB    | ##################################### | 100%
# intel-openmp-2021.4. | 8.8 MB    | ##################################### | 100%
# pyqt-5.9.2           | 5.6 MB    | ##################################### | 100%
# mkl_random-1.2.2     | 332 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import seaborn as sns

bins = np.linspace(df.Principal.min(), df.Principal.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'Principal', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %%
bins = np.linspace(df.age.min(), df.age.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'age', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %% [markdown]
# # Pre-processing:  Feature selection/extraction

# %% [markdown]
# ### Let's look at the day of the week people get the loan

# %%
df['dayofweek'] = df['effective_date'].dt.dayofweek
bins = np.linspace(df.dayofweek.min(), df.dayofweek.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'dayofweek', bins=bins, ec="k")
g.axes[-1].legend()
plt.show()

# %% [markdown]
# We see that people who get the loan at the end of the week don't pay it off, so let's use Feature binarization to set a threshold value less than day 4

# %%
df['weekend'] = df['dayofweek'].apply(lambda x: 1 if (x>3)  else 0)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender  dayofweek  weekend
# 0 2016-10-07   45  High School or Below    male          3        0
# 1 2016-10-07   33              Bechalor  female          3        0
# 2 2016-09-22   27               college    male          3        0
# 3 2016-10-08   28               college  female          4        1
# 4 2016-10-08   29               college    male          4        1

# %% [markdown]
# ## Convert Categorical features to numerical values

# %% [markdown]
# Let's look at gender:

# %%
df.groupby(['Gender'])['loan_status'].value_counts(normalize=True)
# Out:
# Gender  loan_status
# female  PAIDOFF        0.865385
#         COLLECTION     0.134615
# male    PAIDOFF        0.731293
#         COLLECTION     0.268707
# Name: loan_status, dtype: float64

# %% [markdown]
# 86 % of female pay there loans while only 73 % of males pay there loan

# %% [markdown]
# Let's convert male to 0 and female to 1:

# %%
df['Gender'].replace(to_replace=['male','female'], value=[0,1],inplace=True)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender  dayofweek  weekend
# 0 2016-10-07   45  High School or Below       0          3        0
# 1 2016-10-07   33              Bechalor       1          3        0
# 2 2016-09-22   27               college       0          3        0
# 3 2016-10-08   28               college       1          4        1
# 4 2016-10-08   29               college       0          4        1

# %% [markdown]
# ## One Hot Encoding
#
# #### How about education?

# %%
df.groupby(['education'])['loan_status'].value_counts(normalize=True)
# Out:
# education             loan_status
# Bechalor              PAIDOFF        0.750000
#                       COLLECTION     0.250000
# High School or Below  PAIDOFF        0.741722
#                       COLLECTION     0.258278
# Master or Above       COLLECTION     0.500000
#                       PAIDOFF        0.500000
# college               PAIDOFF        0.765101
#                       COLLECTION     0.234899
# Name: loan_status, dtype: float64

# %% [markdown]
# #### Features before One Hot Encoding

# %%
df[['Principal','terms','age','Gender','education']].head()
# Out:
#    Principal  terms  age  Gender             education
# 0       1000     30   45       0  High School or Below
# 1       1000     30   33       1              Bechalor
# 2       1000     15   27       0               college
# 3       1000     30   28       1               college
# 4       1000     30   29       0               college

# %% [markdown]
# #### Use one hot encoding technique to conver categorical varables to binary variables and append them to the feature Data Frame

# %%
Feature = df[['Principal','terms','age','Gender','weekend']]
Feature = pd.concat([Feature,pd.get_dummies(df['education'])], axis=1)
Feature.drop(['Master or Above'], axis = 1,inplace=True)
Feature.head()
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   45       0        0         0                     1
# 1       1000     30   33       1        0         1                     0
# 2       1000     15   27       0        0         0                     0
# 3       1000     30   28       1        1         0                     0
# 4       1000     30   29       0        1         0                     0
#
#    college
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# Let's define feature sets, X:

# %%
X = Feature
X[0:5]
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   45       0        0         0                     1
# 1       1000     30   33       1        0         1                     0
# 2       1000     15   27       0        0         0                     0
# 3       1000     30   28       1        1         0                     0
# 4       1000     30   29       0        1         0                     0
#
#    college
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1

# %% [markdown]
# What are our lables?

# %%
y = df['loan_status'].values
y[0:5]
# Out:
# array(['PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF'],
#       dtype=object)

# %% [markdown]
# ## Normalize Data

# %% [markdown]
# Data Standardization give data zero mean and unit variance (technically should be done after train test split)

# %%
X= preprocessing.StandardScaler().fit(X).transform(X)
X[:,0]
# Out:
# array([ 0.51578458,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458,  0.51578458, -1.31458942, -5.89052444,  0.51578458,
#         0.51578458, -0.39940242,  0.51578458, -1.31458942,  0.51578458,
#         0.51578458,  0.51578458, -1.31458942,  0.51578458,  0.51578458,
#         0.51578458,  0.51578458, -1.31458942,  0.51578458,  0.51578458,
#         0.51578458, -1.31458942,  0.51578458,  0.51578458,  0.51578458,
#        -1.31458942,  0.51578458,  0.51578458,  0.51578458, -1.31458942,
#         0.51578458,  0.51578458,  0.51578458, -1.31458942,  0.51578458,
#         0.51578458, -1.31458942,  0.51578458, -1.31458942,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458,  0.51578458, -1.31458942,
#        -1.31458942,  0.51578458,  0.51578458,  0.51578458, -0.39940242,
#         0.51578458,  0.51578458,  0.51578458, -1.31458942, -1.31458942,
#         0.51578458,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458,  0.51578458, -1.31458942,
#         0.51578458,  0.51578458, -1.31458942, -1.31458942, -1.31458942,
#        -1.31458942,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458, -1.31458942,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458,  0.51578458, -1.31458942,
#         0.51578458,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458, -1.31458942,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458, -1.31458942,  0.51578458,  0.51578458,  0.51578458,
#        -1.31458942,  0.51578458,  0.51578458, -1.31458942,  0.51578458,
#        -1.31458942,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#        -1.31458942, -1.31458942,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458, -1.31458942, -1.31458942, -4.06015044,  0.51578458,
#         0.51578458,  0.51578458, -1.31458942,  0.51578458,  0.51578458,
#         0.51578458, -1.31458942,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#        -1.31458942,  0.51578458, -1.31458942, -1.31458942,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458, -5.89052444,  0.51578458,
#        -1.31458942,  0.51578458,  0.51578458,  0.51578458, -1.31458942,
#        -1.31458942,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#        -1.31458942,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458, -1.31458942,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458, -5.89052444,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#        -1.31458942,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458,  0.51578458, -1.31458942,
#        -1.31458942, -1.31458942,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458, -1.31458942,  0.51578458, -1.31458942,  0.51578458,
#         0.51578458,  0.51578458, -1.31458942, -1.31458942,  0.51578458,
#         0.51578458, -1.31458942, -1.31458942,  0.51578458,  0.51578458,
#        -1.31458942, -4.06015044,  0.51578458,  0.51578458, -1.31458942,
#         0.51578458,  0.51578458,  0.51578458, -1.31458942,  0.51578458,
#        -1.31458942,  0.51578458,  0.51578458, -1.31458942,  0.51578458,
#         0.51578458, -1.31458942,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458,  0.51578458, -1.31458942, -1.31458942,  0.51578458,
#        -1.31458942, -1.31458942, -1.31458942,  0.51578458,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#        -1.31458942,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458, -1.31458942,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458,  0.51578458, -1.31458942, -1.31458942, -1.31458942,
#         0.51578458,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458, -1.31458942,  0.51578458,  0.51578458, -1.31458942,
#         0.51578458,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#        -1.31458942,  0.51578458,  0.51578458, -1.31458942,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458,  0.51578458,  0.51578458,
#        -1.31458942,  0.51578458,  0.51578458, -1.31458942,  0.51578458,
#        -1.31458942, -1.31458942,  0.51578458,  0.51578458, -1.31458942,
#         0.51578458,  0.51578458, -1.31458942,  0.51578458,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458, -1.31458942,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458, -1.31458942,  0.51578458,
#         0.51578458,  0.51578458,  0.51578458, -1.31458942,  0.51578458,
#         0.51578458, -1.31458942,  0.51578458, -1.31458942,  0.51578458,
#         0.51578458])

# %% [markdown]
# # Classification

# %% [markdown]
# Now, it is your turn, use the training set to build an accurate model. Then use the test set to report the accuracy of the model
# You should use the following algorithm:
#
# *   K Nearest Neighbor(KNN)
# *   Decision Tree
# *   Support Vector Machine
# *   Logistic Regression
#
# \__ Notice:\__
#
# *   You can go above and change the pre-processing, feature selection, feature-extraction, and so on, to make a better model.
# *   You should use either scikit-learn, Scipy or Numpy libraries for developing the classification algorithms.
# *   You should include the code of the algorithm in the following cells.

# %% [markdown]
# # K Nearest Neighbor(KNN)
#
# Notice: You should find the best k to build the model with the best accuracy.\
# **warning:** You should not use the **loan_test.csv** for finding the best k, however, you can split your train_loan.csv into train and test to find the best **k**.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (276, 8) (276,)
# Test set: (70, 8) (70,)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k = 4
#Train Model and Predict  
neigh = KNeighborsClassifier(n_neighbors = k)
neigh.fit(X_train,y_train)
neigh
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
yhat = neigh.predict(X_test)
yhat[0:5]
# Out:
# array(['PAIDOFF', 'COLLECTION', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF'],
#       dtype=object)

# %%
# Out:
# Train set Accuracy:  0.8152173913043478
# Test set Accuracy:  0.7

# %% [markdown]
# # Decision Tree

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.3, random_state=3)

# %%
Tree = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
Tree # it shows the default parameters
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
Tree.fit(X_trainset,y_trainset)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
predTree = Tree.predict(X_testset)

# %%
print (predTree [0:5])
print (y_testset [0:5])
# Out:
# ['PAIDOFF' 'PAIDOFF' 'PAIDOFF' 'PAIDOFF' 'PAIDOFF']
# ['PAIDOFF' 'PAIDOFF' 'COLLECTION' 'COLLECTION' 'PAIDOFF']

# %%
# Out:
# DecisionTrees's Accuracy:  0.6538461538461539

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn import svm
clf = svm.SVC(kernel='rbf')
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
ypphat = clf.predict(X_test)
ypphat [0:5]
# Out:
# array(['COLLECTION', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF'],
#       dtype=object)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,y_train)
LR
# Out:
# LogisticRegression(C=0.01, solver='liblinear')

# %%
yprimehat = LR.predict(X_test)
yprimehat
# Out:
# array(['COLLECTION', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'COLLECTION', 'PAIDOFF', 'COLLECTION', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'COLLECTION', 'PAIDOFF', 'PAIDOFF', 'COLLECTION',
#        'COLLECTION', 'PAIDOFF', 'COLLECTION', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'COLLECTION', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'COLLECTION',
#        'PAIDOFF', 'PAIDOFF', 'COLLECTION', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'COLLECTION', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF'], dtype=object)

# %%
yhat_prob = LR.predict_proba(X_test)
yhat_prob
# Out:
# array([[0.5034238 , 0.4965762 ],
#        [0.45206111, 0.54793889],
#        [0.30814132, 0.69185868],
#        [0.34259428, 0.65740572],
#        [0.32025894, 0.67974106],
#        [0.31680537, 0.68319463],
#        [0.48830185, 0.51169815],
#        [0.47823073, 0.52176927],
#        [0.34259428, 0.65740572],
#        [0.4934056 , 0.5065944 ],
#        [0.33806706, 0.66193294],
#        [0.49662231, 0.50337769],
#        [0.24891907, 0.75108093],
#        [0.3419095 , 0.6580905 ],
#        [0.43751789, 0.56248211],
#        [0.25760497, 0.74239503],
#        [0.52357188, 0.47642812],
#        [0.30450278, 0.69549722],
#        [0.50166363, 0.49833637],
#        [0.3195971 , 0.6804029 ],
#        [0.44276988, 0.55723012],
#        [0.49410185, 0.50589815],
#        [0.51350333, 0.48649667],
#        [0.47203498, 0.52796502],
#        [0.40944694, 0.59055306],
#        [0.50846442, 0.49153558],
#        [0.51098415, 0.48901585],
#        [0.37457647, 0.62542353],
#        [0.50418423, 0.49581577],
#        [0.25299635, 0.74700365],
#        [0.46824113, 0.53175887],
#        [0.46024688, 0.53975312],
#        [0.46206917, 0.53793083],
#        [0.48402425, 0.51597575],
#        [0.38818191, 0.61181809],
#        [0.45821326, 0.54178674],
#        [0.50166363, 0.49833637],
#        [0.28973585, 0.71026415],
#        [0.4569882 , 0.5430118 ],
#        [0.45494718, 0.54505282],
#        [0.50670462, 0.49329538],
#        [0.32179362, 0.67820638],
#        [0.45245776, 0.54754224],
#        [0.50846442, 0.49153558],
#        [0.30664231, 0.69335769],
#        [0.49515584, 0.50484416],
#        [0.47075244, 0.52924756],
#        [0.49662231, 0.50337769],
#        [0.45571125, 0.54428875],
#        [0.45567623, 0.54432377],
#        [0.27794059, 0.72205941],
#        [0.46744865, 0.53255135],
#        [0.30501081, 0.69498919],
#        [0.48906194, 0.51093806],
#        [0.28058426, 0.71941574],
#        [0.24921106, 0.75078894],
#        [0.31522806, 0.68477194],
#        [0.43036995, 0.56963005],
#        [0.46824113, 0.53175887],
#        [0.33513632, 0.66486368],
#        [0.41925226, 0.58074774],
#        [0.33133167, 0.66866833],
#        [0.45821326, 0.54178674],
#        [0.52608635, 0.47391365],
#        [0.32399805, 0.67600195],
#        [0.49410185, 0.50589815],
#        [0.33133167, 0.66866833],
#        [0.41737926, 0.58262074],
#        [0.44996108, 0.55003892],
#        [0.32399805, 0.67600195]])

# %% [markdown]
# # Model Evaluation using Test set

# %%
from sklearn.metrics import jaccard_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss

# %% [markdown]
# First, download and load the test set:

# %%
# !wget -O loan_test.csv https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_test.csv
# Out:
# --2022-04-29 14:40:07--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_test.csv
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3642 (3.6K) [text/csv]
# Saving to: ‘loan_test.csv’
#
# loan_test.csv       100%[===================>]   3.56K  --.-KB/s    in 0s
#
# 2022-04-29 14:40:08 (358 MB/s) - ‘loan_test.csv’ saved [3642/3642]

# %% [markdown]
# ### Load Test set for evaluation

# %%
test_df = pd.read_csv('loan_test.csv')
test_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           1             1     PAIDOFF       1000     30       9/8/2016
# 1           5             5     PAIDOFF        300      7       9/9/2016
# 2          21            21     PAIDOFF       1000     30      9/10/2016
# 3          24            24     PAIDOFF       1000     30      9/10/2016
# 4          35            35     PAIDOFF        800     15      9/11/2016
#
#     due_date  age             education  Gender
# 0  10/7/2016   50              Bechalor  female
# 1  9/15/2016   35       Master or Above    male
# 2  10/9/2016   43  High School or Below  female
# 3  10/9/2016   26               college    male
# 4  9/25/2016   29              Bechalor    male

# %%
f1_score(y_test, yhat, average='weighted')
# Out:
# 0.7212490479817212

# %%
jaccard_score(y_test, yhat,pos_label='PAIDOFF')
# Out:
# 0.6557377049180327

# %%
log_loss(y_test, yhat_prob)
# Out:
# 0.5772287609479654

# %% [markdown]
# # Report
#
# You should be able to report the accuracy of the built model using different evaluation metrics:

# %% [markdown]
# | Algorithm          | Jaccard | F1-score | LogLoss |
# | ------------------ | ------- | -------- | ------- |
# | KNN                | ?       | ?        | NA      |
# | Decision Tree      | ?       | ?        | NA      |
# | SVM                | ?       | ?        | NA      |
# | LogisticRegression | ?       | ?        | ?       |

# %% [markdown]
# <h2>Want to learn more?</h2>
#
# IBM SPSS Modeler is a comprehensive analytics platform that has many machine learning algorithms. It has been designed to bring predictive intelligence to decisions made by individuals, by groups, by systems – by your enterprise as a whole. A free trial is available through this course, available here: <a href="http://cocl.us/ML0101EN-SPSSModeler?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2022-01-01">SPSS Modeler</a>
#
# Also, you can use Watson Studio to run these notebooks faster with bigger datasets. Watson Studio is IBM's leading cloud solution for data scientists, built by data scientists. With Jupyter notebooks, RStudio, Apache Spark and popular libraries pre-packaged in the cloud, Watson Studio enables data scientists to collaborate on their projects without having to install anything. Join the fast-growing community of Watson Studio users today with a free account at <a href="https://cocl.us/ML0101EN_DSX?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2022-01-01">Watson Studio</a>
#
# <h3>Thanks for completing this lesson!</h3>
#
# <h4>Author:  <a href="https://ca.linkedin.com/in/saeedaghabozorgi?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2022-01-01?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2022-01-01">Saeed Aghabozorgi</a></h4>
# <p><a href="https://ca.linkedin.com/in/saeedaghabozorgi">Saeed Aghabozorgi</a>, PhD is a Data Scientist in IBM with a track record of developing enterprise level applications that substantially increases clients’ ability to turn data into actionable knowledge. He is a researcher in data mining field and expert in developing advanced analytic methods like machine learning and statistical modelling on large datasets.</p>
#
# <hr>
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By    | Change Description                                                             |
# | ----------------- | ------- | ------------- | ------------------------------------------------------------------------------ |
# | 2020-10-27        | 2.1     | Lakshmi Holla | Made changes in import statement due to updates in version of  sklearn library |
# | 2020-08-27        | 2.0     | Malika Singla | Added lab to GitLab                                                            |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
#
# <p>
